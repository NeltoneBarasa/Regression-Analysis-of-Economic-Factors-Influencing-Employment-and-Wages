# %%
#Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading Dataset
df_qcew = pd.read_csv("C:\\Users\\USER\\OneDrive\\Desktop\\qcew_2016-2019.csv")
df_qcew.head()
# Out:
#   Area Type       Area Name  Year  Quarter           Ownership  NAICS Level  \
# 0    County  Alameda County  2016  1st Qtr  Federal Government            2
# 1    County  Alameda County  2016  1st Qtr  Federal Government            2
# 2    County  Alameda County  2016  1st Qtr             Private            5
# 3    County  Alameda County  2016  1st Qtr             Private            4
# 4    County  Alameda County  2016  1st Qtr             Private            5
#
#   NAICS Code                        Industry Name  Establishments  \
# 0       1023                 Financial Activities               1
# 1       1028                Public Administration              72
# 2      11121          Vegetable and Melon Farming               7
# 3       1114    Greenhouse and Nursery Production               7
# 4      11142  Nursery and Floriculture Production               7
#
#    Average Monthly Employment  1st Month Emp  2nd Month Emp  3rd Month Emp  \
# ...

# %%
#Dependent and independent Variables
dependent_variable = 'Average Monthly Employment'
simplified_independent_variables = ['Establishments', 'Total Wages (All Workers)', 'Year']

# %%
# !pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import statsmodels.api as sm
# Prepare the data for regression
categorical_vars = []  # No categorical variables for simplification
df_regression_simplified = df_qcew[[dependent_variable] + simplified_independent_variables]

y_simplified = df_regression_simplified[dependent_variable]
X_simplified = df_regression_simplified.drop(columns=[dependent_variable])
X_simplified = sm.add_constant(X_simplified)

# %%
# Fit the simplified regression model
model_simplified = sm.OLS(y_simplified, X_simplified).fit()
model_simplified_summary = model_simplified.summary()
model_simplified_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     Average Monthly Employment   R-squared:                       0.964
# Model:                                    OLS   Adj. R-squared:                  0.964
# Method:                         Least Squares   F-statistic:                 9.137e+06
# Date:                        Tue, 19 Nov 2024   Prob (F-statistic):               0.00
# Time:                                17:21:32   Log-Likelihood:            -1.3895e+07
# No. Observations:                     1009955   AIC:                         2.779e+07
# Df Residuals:                         1009951   BIC:                         2.779e+07
# Df Model:                                   3
# Covariance Type:                    nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ...
